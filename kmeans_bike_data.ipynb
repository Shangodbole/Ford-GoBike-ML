# %%
import pandas as pd

# Import the data 
bike_201801 = pd.read_csv("201801-fordgobike-tripdata.csv")
bike_201802 = pd.read_csv("201802-fordgobike-tripdata.csv")
bike_201803 = pd.read_csv("201803-fordgobike-tripdata.csv")
bike_201804 = pd.read_csv("201804-fordgobike-tripdata.csv")
bike_201805 = pd.read_csv("201805-fordgobike-tripdata.csv")
bike_201806 = pd.read_csv("201806-fordgobike-tripdata.csv")
bike_201807 = pd.read_csv("201801-fordgobike-tripdata.csv")
bike_201808 = pd.read_csv("201802-fordgobike-tripdata.csv")
bike_201809 = pd.read_csv("201803-fordgobike-tripdata.csv")
bike_201810 = pd.read_csv("201804-fordgobike-tripdata.csv")
bike_201811 = pd.read_csv("201805-fordgobike-tripdata.csv")
bike_201812 = pd.read_csv("201806-fordgobike-tripdata.csv")

# Bike data 2017
bike_2017 = pd.read_csv("2017-fordgobike-tripdata.csv")

# %%
bike_201801.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         75284  2018-01-31 22:52:35.2390  2018-02-01 19:47:19.8240
# 1         85422  2018-01-31 16:13:34.3510  2018-02-01 15:57:17.3100
# 2         71576  2018-01-31 14:23:55.8890  2018-02-01 10:16:52.1160
# 3         61076  2018-01-31 14:53:23.5620  2018-02-01 07:51:20.5000
# 4         39966  2018-01-31 19:52:24.6670  2018-02-01 06:58:31.0530
#
#    start_station_id                                 start_station_name  \
# 0               120                               Mission Dolores Park
# 1                15  San Francisco Ferry Building (Harry Bridges Pl...
# 2               304                               Jackson St at 5th St
# 3                75                           Market St at Franklin St
# 4                74                              Laguna St at Hayes St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
import numpy as np
from random import sample

# %%
sample_bike_2017 = bike_2017.sample(n=10000)

# %%
sample_bike_2017.shape
# Out:
# (10000, 15)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (16,14))

# %%
plt.scatter(sample_bike_2017.start_station_id,sample_bike_2017.duration_sec)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(sample_bike_2017.start_station_id, sample_bike_2017.end_station_id, sample_bike_2017.duration_sec, c='r')

# %%
sample_bike_2017.head()
# Out:
#         duration_sec                start_time                  end_time  \
# 99659            710  2017-11-27 19:32:12.1130  2017-11-27 19:44:02.2540
# 408289           547  2017-08-25 17:44:28.2510  2017-08-25 17:53:35.9000
# 501023           491  2017-07-16 14:35:40.5190  2017-07-16 14:43:51.7000
# 261926          2346  2017-10-09 11:14:28.2000  2017-10-09 11:53:35.1880
# 471048           595  2017-08-01 18:26:17.8820  2017-08-01 18:36:13.2490
#
#         start_station_id                   start_station_name  \
# 99659                 14                Clay St at Battery St
# 408289                37                  2nd St at Folsom St
# 501023               240            Haste St at Telegraph Ave
# 261926               141       Valencia St at Cesar Chavez St
# 471048               324  Union Square (Powell St at Post St)
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 99659                37.795001              -122.399970              45
# ...

# %%
sample_bike_2017.dtypes
# Out:
# duration_sec                 int64
# start_time                  object
# end_time                    object
# start_station_id             int64
# start_station_name          object
# start_station_latitude     float64
# start_station_longitude    float64
# end_station_id               int64
# end_station_name            object
# end_station_latitude       float64
# end_station_longitude      float64
# bike_id                      int64
# user_type                   object
# member_birth_year          float64
# member_gender               object
# dtype: object

# %%
sample_bike_2017['Start_Date'], sample_bike_2017['Start_Time'] = sample_bike_2017.start_time.str.split(' ', 1).str

# %%
sample_bike_2017.dtypes
# Out:
# duration_sec                 int64
# start_time                  object
# end_time                    object
# start_station_id             int64
# start_station_name          object
# start_station_latitude     float64
# start_station_longitude    float64
# end_station_id               int64
# end_station_name            object
# end_station_latitude       float64
# end_station_longitude      float64
# bike_id                      int64
# user_type                   object
# member_birth_year          float64
# member_gender               object
# Start_Date                  object
# Start_Time                  object
# dtype: object

# %%
sample_bike_2017.head(5)
# Out:
#         duration_sec                start_time                  end_time  \
# 99659            710  2017-11-27 19:32:12.1130  2017-11-27 19:44:02.2540
# 408289           547  2017-08-25 17:44:28.2510  2017-08-25 17:53:35.9000
# 501023           491  2017-07-16 14:35:40.5190  2017-07-16 14:43:51.7000
# 261926          2346  2017-10-09 11:14:28.2000  2017-10-09 11:53:35.1880
# 471048           595  2017-08-01 18:26:17.8820  2017-08-01 18:36:13.2490
#
#         start_station_id                   start_station_name  \
# 99659                 14                Clay St at Battery St
# 408289                37                  2nd St at Folsom St
# 501023               240            Haste St at Telegraph Ave
# 261926               141       Valencia St at Cesar Chavez St
# 471048               324  Union Square (Powell St at Post St)
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 99659                37.795001              -122.399970              45
# ...

# %%
import pixiedust

# %%
# %%pixie_debugger
a = 0
for i, row in sample_bike_2017.iterrows():
    row['bike_id'] <- 2

# %%
sample_bike_2017.tail(2)
# Out:
#         duration_sec                start_time                  end_time  \
# 373252           248  2017-09-06 20:34:08.1840  2017-09-06 20:38:16.5570
# 212968           366  2017-10-23 18:12:24.5860  2017-10-23 18:18:30.6840
#
#         start_station_id    start_station_name  start_station_latitude  \
# 373252               100  Bryant St at 15th St               37.767100
# 212968                79  7th St at Brannan St               37.773492
#
#         start_station_longitude  end_station_id       end_station_name  \
# 373252              -122.410662              90  Townsend St at 7th St
# 212968              -122.403673              36    Folsom St at 3rd St
#
#         end_station_latitude  end_station_longitude  bike_id   user_type  \
# 373252             37.771058            -122.402717     1735  Subscriber
# 212968             37.783830            -122.398870     2460  Subscriber
#
#         member_birth_year member_gender  Start_Date     Start_Time
# ...

# %%
sample_bike_2017.plot(kind = 'Scatter', x = 'bike_id',y='duration_sec')

# %%
import math

def get_distance(lat_1, lng_1, lat_2, lng_2): 
    d_lat = lat_2 - lat_1
    d_lng = lng_2 - lng_1 

    temp = (  
         math.sin(d_lat / 2) ** 2 
       + math.cos(lat_1) 
       * math.cos(lat_2) 
       * math.sin(d_lng / 2) ** 2
    )

    return 6373.0 * (2 * math.atan2(math.sqrt(temp), math.sqrt(1 - temp)))

# %%
sample_bike_2017['distance'] = 0

# %%
for i, row in sample_bike_2017.iterrows():
    sample_bike_2017.at[i,'distance'] = get_distance(row['start_station_latitude'],
                                                     row['start_station_longitude'],
                                                     row['end_station_latitude'],
                                                     row['end_station_longitude'])

# %%
sample_bike_2017.plot(kind = 'Scatter', x = 'distance',y='duration_sec')

# %%
sample_bike_2017[sample_bike_2017.distance<10];

# %%
import numpy as np
import googlemaps

# %%
gmaps = googlemaps.Client(key = "AIzaSyAnjviNaMvfKyG4G0ZZKFv9CWIaIo21BiY")

# %%
result = gmaps.geocode('Brandon,Mississippi')
result
# Out:
# [{'address_components': [{'long_name': 'Brandon',
#     'short_name': 'Brandon',
#     'types': ['locality', 'political']},
#    {'long_name': 'Rankin County',
#     'short_name': 'Rankin County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Mississippi',
#     'short_name': 'MS',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Brandon, MS, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 32.3129289,
#      'lng': -89.93705589999999},
#     'southwest': {'lat': 32.2397349, 'lng': -90.0418069}},
#    'location': {'lat': 32.2732024, 'lng': -89.9859158},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 32.3129289, 'lng': -89.93705589999999},
#     'southwest': {'lat': 32.2397349, 'lng': -90.0418069}}},
#   'place_id': 'ChIJ45RzlVssKIYRThNpIUZsceM',
# ...

# %%
result[0]['address_components'][0]['long_name']
# Out:
# 'Brandon'

# %%
gmaps.reverse_geocode((32.3129289,-89.93705589999999));

# %%
sample_bike_2017.shape
# Out:
# (10000, 18)

# %%
# import time
# loop_cnt = 0
# for i, row in sample_bike_2017.iterrows():
#     loop_cnt = loop_cnt + 1
#     result = gmaps.reverse_geocode((row['start_station_latitude'],row['start_station_longitude']))
#     sample_bike_2017.at[i,'city'] = result[0]['address_components'][2]['long_name']
#     if loop_cnt % 10 == 0:
#         time.sleep(2)

# %%
# Import the Weather Station Site List Data
site_list = pd.read_csv("SiteList.csv")

# %%
site_list.head()
# Out:
#   Site4              City TimeZone  OffUTC State        Lat         Lon  \
# 0  CWAJ     ERIEAU (MAPS)      EST      -5    ON  42.250000  -81.900000
# 1  CWBE  KILLARNEY (MAPS)      EST      -5    ON  45.966667  -81.466667
# 2  CWBZ         ST ANICET      EST      -5    QC  45.116667  -74.266667
# 3  CWFJ    CARDSTON (AUT)      MST      -7    AB  49.200000 -113.266667
# 4  CWGD  GODERICH (AUTO8)      EST      -5    ON  43.766667  -81.716667
#
#    Elevation(feet)
# 0              584
# 1              643
# 2              161
# 3             3727
# 4              702

# %%
site_list = site_list.drop(site_list[(site_list.TimeZone != 'PST')].index)

# %%
def get_closest_city(lat_1, lng_1):
    
    shortest_distance = 100000
    closest_city = None
    closest_distance = None
    
    for i, row in site_list.iterrows():
        lat_2 = row['Lat']
        lng_2 = row['Lon']
         
        d_lat = lat_2 - lat_1
        d_lng = lng_2 - lng_1 

        temp = (  
          math.sin(d_lat / 2) ** 2 
        + math.cos(lat_1) 
        * math.cos(lat_2) 
        * math.sin(d_lng / 2) ** 2
        )

        distance =  6373.0 * (2 * math.atan2(math.sqrt(temp), math.sqrt(1 - temp)))
    
        if distance < shortest_distance:
            closest_distance = distance
            closest_city = row['City']
            closest_site = row['Site4']
            shortest_distance = distance

    return closest_city, closest_site

# %%
# %%pixie_debugger
for i, row in sample_bike_2017.iterrows():
    sample_bike_2017.at[i,'closest_city'], sample_bike_2017.at[i,'Site']= get_closest_city(row['start_station_latitude'],
                                                            row['start_station_longitude'])

# %%
sample_bike_2017.head(10)
# Out:
#         duration_sec                start_time                  end_time  \
# 99659            710  2017-11-27 19:32:12.1130  2017-11-27 19:44:02.2540
# 408289           547  2017-08-25 17:44:28.2510  2017-08-25 17:53:35.9000
# 501023           491  2017-07-16 14:35:40.5190  2017-07-16 14:43:51.7000
# 261926          2346  2017-10-09 11:14:28.2000  2017-10-09 11:53:35.1880
# 471048           595  2017-08-01 18:26:17.8820  2017-08-01 18:36:13.2490
# 93913            381  2017-11-29 09:21:29.6000  2017-11-29 09:27:50.9950
# 460280           543  2017-08-06 15:42:29.9210  2017-08-06 15:51:33.3170
# 39866            550  2017-12-14 08:26:25.7400  2017-12-14 08:35:35.8030
# 245855           630  2017-10-13 17:13:25.8860  2017-10-13 17:23:56.0100
# 107181          6197  2017-11-23 18:08:08.0290  2017-11-23 19:51:25.7340
#
#         start_station_id                                 start_station_name  \
# 99659                 14                              Clay St at Battery St
# ...

# %%
sample_bike_2017['Date'] = pd.to_datetime(sample_bike_2017.start_time)

# %%
sample_bike_2017.Date.dt.date
# Out:
# 99659     2017-11-27
# 408289    2017-08-25
# 501023    2017-07-16
# 261926    2017-10-09
# 471048    2017-08-01
# 93913     2017-11-29
# 460280    2017-08-06
# 39866     2017-12-14
# 245855    2017-10-13
# 107181    2017-11-23
# 336743    2017-09-18
# 405331    2017-08-27
# 156760    2017-11-08
# 19443     2017-12-20
# 457767    2017-08-07
# 387523    2017-09-01
# 143452    2017-11-11
# 342021    2017-09-16
# 122907    2017-11-17
# 475499    2017-07-30
# 166562    2017-11-05
# 226235    2017-10-19
# 27456     2017-12-18
# 79009     2017-12-03
# 88221     2017-11-30
# 433955    2017-08-16
# 353963    2017-09-12
# 169072    2017-11-04
# 361452    2017-09-10
# 417920    2017-08-22
#              ...
# 507452    2017-07-11
# 113331    2017-11-21
# 458846    2017-08-07
# 15001     2017-12-21
# 127988    2017-11-16
# 65375     2017-12-07
# 137856    2017-11-13
# 499755    2017-07-17
# 364247    2017-09-09
# 200167    2017-10-26
# 437222    2017-08-15
# 459814    2017-08-06
# ...

# %%
# Import the Weather  Data
Weather_data = pd.read_csv("HourlyData2017.txt",sep=',',low_memory=False)

# %%
Weather_data.head()
# Out:
#    Site                Date  Hour  Temperature  Dewpoint  RH WindDir  \
# 0  CYXX  11/15/2017 0:00:00     7           46        39  76     140
# 1  CYXX  11/15/2017 0:00:00     8           45        39  81     170
# 2  CYXX  11/15/2017 0:00:00     9           45        41  86     170
# 3  CYXX  11/15/2017 0:00:00    10           45        43  93     200
# 4  CYXX  11/15/2017 0:00:00     6           46        40  79     140
#
#    Windspeed  CldFrac   MSLP Weather  Precip  Source
# 0         14      1.0  29.60     -RA     0.0     NWS
# 1         16      1.0  29.63     OVC     0.0     NWS
# 2         14      1.0  29.64     OVC     NaN  Filled
# 3         13      1.0  29.64   -SHRA     0.0     NWS
# 4         12      1.0  29.61     OVC     NaN  Filled

# %%
Weather_data['Date'] = pd.to_datetime(Weather_data.Date)

# %%
Weather_data.head()
# Out:
#    Site       Date  Hour  Temperature  Dewpoint  RH WindDir  Windspeed  \
# 0  CYXX 2017-11-15     7           46        39  76     140         14
# 1  CYXX 2017-11-15     8           45        39  81     170         16
# 2  CYXX 2017-11-15     9           45        41  86     170         14
# 3  CYXX 2017-11-15    10           45        43  93     200         13
# 4  CYXX 2017-11-15     6           46        40  79     140         12
#
#    CldFrac   MSLP Weather  Precip  Source      Date_1
# 0      1.0  29.60     -RA     0.0     NWS  11/15/2017
# 1      1.0  29.63     OVC     0.0     NWS  11/15/2017
# 2      1.0  29.64     OVC     NaN  Filled  11/15/2017
# 3      1.0  29.64   -SHRA     0.0     NWS  11/15/2017
# 4      1.0  29.61     OVC     NaN  Filled  11/15/2017

# %%
sample_bike_2017.Date_1 = sample_bike_2017.Date.dt.date

# %%
sample_bike_2017['Hour'] = sample_bike_2017.Date.dt.hour

# %%
Weather_data.Date_1 = Weather_data.Date.dt.date

# %%
sample_bike_2017.head()
# Out:
#         duration_sec                start_time                  end_time  \
# 99659            710  2017-11-27 19:32:12.1130  2017-11-27 19:44:02.2540
# 408289           547  2017-08-25 17:44:28.2510  2017-08-25 17:53:35.9000
# 501023           491  2017-07-16 14:35:40.5190  2017-07-16 14:43:51.7000
# 261926          2346  2017-10-09 11:14:28.2000  2017-10-09 11:53:35.1880
# 471048           595  2017-08-01 18:26:17.8820  2017-08-01 18:36:13.2490
#
#         start_station_id                   start_station_name  \
# 99659                 14                Clay St at Battery St
# 408289                37                  2nd St at Folsom St
# 501023               240            Haste St at Telegraph Ave
# 261926               141       Valencia St at Cesar Chavez St
# 471048               324  Union Square (Powell St at Post St)
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 99659                37.795001              -122.399970              45
# ...

# %%
Weather_data.head()
# Out:
#    Site       Date  Hour  Temperature  Dewpoint  RH WindDir  Windspeed  \
# 0  CYXX 2017-11-15     7           46        39  76     140         14
# 1  CYXX 2017-11-15     8           45        39  81     170         16
# 2  CYXX 2017-11-15     9           45        41  86     170         14
# 3  CYXX 2017-11-15    10           45        43  93     200         13
# 4  CYXX 2017-11-15     6           46        40  79     140         12
#
#    CldFrac   MSLP Weather  Precip  Source      Date_1
# 0      1.0  29.60     -RA     0.0     NWS  2017-11-15
# 1      1.0  29.63     OVC     0.0     NWS  2017-11-15
# 2      1.0  29.64     OVC     NaN  Filled  2017-11-15
# 3      1.0  29.64   -SHRA     0.0     NWS  2017-11-15
# 4      1.0  29.61     OVC     NaN  Filled  2017-11-15

# %%
sample_bike_2017=sample_bike_2017.merge(Weather_data[['Date_1','Hour','Site','Temperature','Windspeed','Precip']],
                                        on=['Site','Date_1','Hour'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6554f79ad67b> in <module>
# ----> 1 sample_bike_2017=sample_bike_2017.merge(Weather_data[['Date_1','Hour','Site','Temperature','Windspeed','Precip']],
#       2                                         on=['Site','Date_1','Hour'])
#
# NameError: name 'sample_bike_2017' is not defined

# %%
sample_bike_2017
# Out:
#       duration_sec                start_time                  end_time  \
# 0              710  2017-11-27 19:32:12.1130  2017-11-27 19:44:02.2540
# 1              673  2017-11-27 19:16:23.0380  2017-11-27 19:27:36.8900
# 2             1644  2017-11-27 19:02:23.2160  2017-11-27 19:29:47.6340
# 3              547  2017-08-25 17:44:28.2510  2017-08-25 17:53:35.9000
# 4              661  2017-08-25 17:29:01.3630  2017-08-25 17:40:02.5340
# 5              573  2017-08-25 17:45:07.9780  2017-08-25 17:54:41.1900
# 6              976  2017-08-25 17:56:06.7180  2017-08-25 18:12:23.4780
# 7              230  2017-08-25 17:48:43.6660  2017-08-25 17:52:34.4850
# 8              721  2017-08-25 17:55:05.6880  2017-08-25 18:07:07.4750
# 9              209  2017-08-25 17:36:36.0560  2017-08-25 17:40:05.3720
# 10             638  2017-08-25 17:07:38.1940  2017-08-25 17:18:16.9200
# 11             491  2017-07-16 14:35:40.5190  2017-07-16 14:43:51.7000
# ...

# %%
sample_bike_2017.to_csv('Final_2017_data')

# %%
from sklearn.cluster import KMeans

# %%
x = sample_bike_2017[['duration_sec','Temperature','Precip']]

# %%
x.Precip[x.Precip.isnull()] = 0
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:7626: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3267: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
k_means = KMeans(n_clusters = 3,random_state=0).fit(x)

# %%
print(k_means.labels_)
# Out:
# [0 0 0 ... 0 2 0]

# %%
x['cluster'] = k_means.labels_
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x
# Out:
#       duration_sec  Temperature  Precip  cluster
# 0              710           54    0.00        0
# 1              673           54    0.00        0
# 2             1644           54    0.00        0
# 3              547           62    0.00        0
# 4              661           62    0.00        0
# 5              573           62    0.00        0
# 6              976           62    0.00        0
# 7              230           62    0.00        0
# 8              721           62    0.00        0
# 9              209           62    0.00        0
# 10             638           62    0.00        0
# 11             491           83    0.00        0
# 12            2346           74    0.00        0
# 13             572           74    0.00        0
# 14             595           64    0.00        0
# 15             548           64    0.00        0
# 16             431           64    0.00        0
# 17            1125           64    0.00        0
# ...

# %%
x[x.cluster==2]
# Out:
#       duration_sec  Temperature  Precip  cluster
# 53           21017           53  0.0000        2
# 228           8362           84  0.0000        2
# 285          10404           69  0.0000        2
# 455           8139           67  0.0000        2
# 535          18762           63  0.0000        2
# 604          17953           55  0.0000        2
# 644          13270           66  0.0000        2
# 863          14028           73  0.0000        2
# 914           7748           71  0.0000        2
# 1111         25258           65  0.0000        2
# 1204         12819           57  0.0000        2
# 1206         16179           57  0.0000        2
# 1289         12909           80  0.0000        2
# 1291         11749           80  0.0000        2
# 1455         10938           67  0.0000        2
# 1527          9912           70  0.0000        2
# 1589          8672           55  0.0000        2
# 1640         13852           63  0.0000        2
# ...

# %%
x.plot(kind = 'Scatter', x = 'duration_sec',y='Temperature')

# %%
k_means.cluster_centers_
# Out:
# array([[8.05242464e+02, 6.28830813e+01, 1.71551812e-04],
#        [5.88075294e+04, 6.34117647e+01, 2.71050543e-20],
#        [1.46098923e+04, 6.60076923e+01, 6.93846154e-04]])

# %%
x1 = sample_bike_2017[['duration_sec','Temperature']]
k_means1 = KMeans(n_clusters = 6,random_state=0).fit(x1)
x1['cluster'] = k_means1.labels_
k_means1.cluster_centers_
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[6.85566176e+02, 6.28042017e+01],
#        [6.98229000e+04, 6.45000000e+01],
#        [2.28204286e+04, 6.34285714e+01],
#        [4.28004438e+03, 6.50917160e+01],
#        [3.96817273e+04, 6.13636364e+01],
#        [1.16787419e+04, 6.72365591e+01]])

# %%
sample_bike_2017.plot(kind = 'Scatter', x = 'Windspeed',y='duration_sec')

# %%
x1 = sample_bike_2017[['duration_sec','Temperature','start_station_id']]
x1.duration_sec = (x1.duration_sec/60)
k_means1 = KMeans(n_clusters = 3,random_state=0).fit(x1)
x1['cluster'] = k_means1.labels_
k_means1.cluster_centers_
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# array([[ 15.21064073,  63.20743034,  50.61058016],
#        [ 15.98235837,  62.08537549, 220.84822134],
#        [661.36382114,  63.46341463, 103.43902439]])

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(x1.duration_sec,x1.Temperature,x1.start_station_id, c='r')
